# %% [markdown]
# ## LANGCHAIN - PASO A PASO

# %% [markdown]
# ### 1. CONECTAR EL LLM

# %%
# !pip install -U langchain "langchain[google-genai]"
# Out:
# Collecting U
#   Downloading u-4.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: langchain in /usr/local/lib/python3.13/dist-packages (1.3.17)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.13/dist-packages (from U) (4.16.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.6.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain) (2.13.4)
# Collecting langchain-google-genai (from langchain[google-genai])
#   Downloading langchain_google_genai-4.4.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.3)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai->langchain[google-genai])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<3.0.0,>=2.20.0 (from langchain-google-genai->langchain[google-genai])
#   Downloading google_genai-2.22.0-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.7 MB/s eta 0:00:00
# Collecting langchain-core<2.0.0,>=1.6.0 (from langchain)
#   Downloading langchain_core-1.6.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (4.14.2)
# Collecting google-auth<3.0.0,>=2.56.0 (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai])
#   Downloading google_auth-2.57.1-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (2.32.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.25.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (50.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai->langchain[google-genai]) (3.0)
# Downloading u-4.0-py3-none-any.whl (31 kB)
# Downloading langchain_google_genai-4.4.0-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 3.6 MB/s eta 0:00:00
# Downloading langchain_core-1.6.2-py3-none-any.whl (571 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.7/571.7 kB 20.5 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_genai-2.22.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.5 MB/s eta 0:00:00
# Downloading google_auth-2.57.1-py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: filetype, U, google-auth, langchain-core, google-genai, langchain-google-genai
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.49.0
#     Uninstalling google-auth-2.49.0:
#       Successfully uninstalled google-auth-2.49.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.6.0
#     Uninstalling langchain-core-1.6.0:
#       Successfully uninstalled langchain-core-1.6.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.12.1
#     Uninstalling google-genai-2.12.1:
#       Successfully uninstalled google-genai-2.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.57.1 which is incompatible.
# Successfully installed U-4.0 filetype-1.2.0 google-auth-2.57.1 google-genai-2.22.0 langchain-core-1.6.2 langchain-google-genai-4.4.0

# %% [markdown]
# ## Agente = Modelo + Arnés (Harness).
# LangChain proporciona create_agent: un arnés mínimo y altamente configurable. El arnés es todo lo que rodea al bucle del modelo: el prompt, las herramientas y cualquier middleware que moldee el comportamiento. Comienza con las primitivas y compone exactamente lo que tu caso de uso necesita. Soporta OpenAI, Anthropic, Google y más."
#
# ------------------------------
#
# ## El Paradigma de "Agent Harness" en LangChain
# ### 1. Definición Clara y Técnica
# En el desarrollo de aplicaciones de Inteligencia Artificial modernas, la arquitectura ha evolucionado desde los simples "wrappers" (envoltorios de código) hacia el concepto de Agent Harness (Arnés del Agente).
#
# Técnicamente, un Harness es la infraestructura, entorno de ejecución y sistema de control que envuelve al ciclo de inferencia del LLM (el bucle del modelo). Mientras que el LLM funciona como el "motor cognitivo" aislado, el arnés actúa como el "chasis y los sistemas operativos" que le permiten interactuar de forma segura, estructurada y autónoma con el mundo real.
#
# ### 2. Capas de Ingeniería en el Ecosistema Actual
# El desarrollo con LLMs se divide ahora en tres niveles concéntricos de ingeniería:
#
#    1. **Prompt Engineering:** Diseñar las instrucciones de texto exactas que recibe el modelo.
#    2. **Context Engineering:** Administrar qué datos específicos ve el modelo en su ventana de contexto y cuándo los ve.
#    3. **Harness Engineering (El enfoque actual):** Engloba las dos anteriores y añade la orquestación de herramientas (Tool Calling), la persistencia del estado (memoria), la gestión de errores, los bucles de verificación y la seguridad del sistema.
#
# ### 3. ¿Por qué es la "Nueva Forma" de Conectar LLMs?
# Anteriormente, conectar un LLM implicaba encadenar componentes de forma rígida (las antiguas Chains secuenciales de LangChain). El enfoque moderno basado en create_agent y abstracciones de arnés ofrece:
#
# **Neutralidad de Modelos (Model Agnostic):** El arnés abstrae la API subyacente. Puedes intercambiar el motor (OpenAI, Anthropic, Google) sin reescribir la lógica de tus herramientas ni de tu memoria.
#
# **Middleware Configurable:** Permite interceptar las peticiones y respuestas para inyectar lógica personalizada (ej. control de costos, compresión de historial o seguridad) antes y después de que el LLM actúe.
#
# **Arquitectura de Bucle Abierto:** En lugar de ejecutar una sola petición, el arnés gestiona de manera autónoma un ciclo repetitivo: evalúa el prompt → llama al LLM → ejecuta herramientas si es necesario → procesa resultados → vuelve a preguntar al LLM.

# %%
import os

from langchain.agents import create_agent
from google.colab import userdata

# Traer la API_KEY desde las variables de entorno (en esta caso desde un notebook en google colab)
# Esto evita exponer claves privadas al compartir el notebook (recuerde colocar la suya, en este caso la free de google)
os.environ["GEMINI_API_KEY"] = userdata.get('GEMINI_API_KEY')

# 1. Inicializamos el arnés conversacional puro
agent = create_agent(
    model = "google_genai:gemini-3.6-flash",
    system_prompt="You are an expert Artificial Intelligence tutor. Provide concise and clear explanations. Answer in spanish",
)

# 2. El arnés se ejecuta enviando el estado de la conversación (messages)
# El usuario interactúa de forma directa mediante texto estructurado
result = agent.invoke(
    {
        "messages":
        [
            {
                "role": "user",
                "content": "Explain what an 'Agent Harness' is in one sentence."

            }
        ]
    }
)

# 3. Inspecionamos el Output de el LLM
# Recuperamos el último mensaje del historial retornado por el arnés.
last_message = result["messages"][-1]

# Opción A: Inspección de la estructura interna unificada (content_blocks)
print("--- Content Blocks Structure ---")
# Respuesta completa - print(last_message.content_blocks)
# Respuesta limpia
print(f"AI 🤖: {last_message.content_blocks[0].get("text", "")}")

# Opción B: Extracción del texto limpio (La recomendada para producción)
print("\n--- Final Text Output ---")
# Respuesta completa - print(last_message.content)
# Respuesta limpia
print(f"AI 🤖: {last_message.content[0].get("text", "")}")
# Out:
# --- Content Blocks Structure ---
# AI 🤖: Un **Agent Harness** es la infraestructura de software que envuelve a un agente de IA para gestionar su ejecución, proporcionarle acceso a memoria y herramientas, y controlar de forma segura sus interacciones con el entorno.
#
# --- Final Text Output ---
# AI 🤖: Un **Agent Harness** es la infraestructura de software que envuelve a un agente de IA para gestionar su ejecución, proporcionarle acceso a memoria y herramientas, y controlar de forma segura sus interacciones con el entorno.

# %% [markdown]
# En la arquitectura moderna de LangChain, el método create_agent está diseñado con una filosofía minimalista: el arnés no debe duplicar los parámetros del modelo.
#
# Por lo tanto, create_agent se divide en dos tipos de propiedades: los parámetros estructurales del arnés y los parámetros de generación de hiperparámetros (que se inyectan a través del string de configuración o diccionarios).
#
# ------------------------------
# ## 1. Parámetros de Estructura (Directos en create_agent)
# Son las propiedades nativas que definen qué puede hacer el arnés del agente:
#
#
# **model (str | BaseChatModel):** El identificador único ("google:gemini-2.5-flash", "openai:gpt-4o-mini").
#
# **system_prompt (str | SystemMessage):** Define las reglas del sistema, el rol, las restricciones y el idioma de respuesta.
#
# **tools (list[Callable | BaseTool]):** Lista de funciones nativas de Python que el agente puede invocar en su bucle operativo.
#
# **response_format (BaseModel | TypedDict | dict):** (¡Muy importante en 2026!) Fuerza al agente a retornar un formato estructurado (usando una clase Pydantic) en lugar de texto plano, ideal para extraer JSON estructurado automáticamente.
#
# **middleware (list):** Lista de capas o interceptores para auditar costos, inyectar seguridad, formatear el historial o detener ejecuciones inapropiadas.
#
# ------------------------------
# ## 2. Parámetros del Modelo (temperature, max_tokens, etc.)
# Para modificar los parámetros cognitivos del LLM (hiperparámetros), no se pasan directamente a create_agent, sino que se configuran de dos maneras según el nivel del curso que estés dictando:
#
# ### Método A: Al inicializar el modelo (Para scripts locales avanzados)
# Si en lugar de pasar un string pasas la instancia del objeto, puedes configurar el comportamiento exacto. Daremos un ejemplo de este metodo, a traves de las clases de integracion de langchain en este caso con google-genai
# https://docs.langchain.com/oss/python/integrations/chat/google_generative_ai
#
# ### Método B: Mediante Models (init_chat_model)
# En producción, instanciar modelos de forma directa (como ChatGoogleGenerativeAI) genera código rígido y acoplado a un solo proveedor.
#
# La sintaxis moderna y recomendada es usar init_chat_model para inicializar el motor cognitivo (por su flexibilidad de configuración) y pasárselo de inmediato al arnés create_agent.Por otro lado te permite cambiar de proveedor de IA con variables de entorno sin modificar una sola línea de código Python (es Model Agnostic).
# https://docs.langchain.com/oss/python/langchain/models
#
# ### Método C: Mediante Perfiles de Arnés (Harness Profiles)
# En las versiones actuales de LangChain, puedes pasar diccionarios de configuración en el método .invoke() o registrar perfiles globales (HarnessProfile) para que el mismo string "google:gemini..." aplique restricciones dinámicas en caliente sin reconstruir el objeto. Este metodo tiene un nivel de complejidad medio-avanzado asi que se dejara para capitulos posteriores, si deseas leer al respecto:
# https://learn.microsoft.com/en-us/agent-framework/concepts/agents/running-agents?pivots=programming-language-python
#
# ------------------------------
#
# ### Tabla Comparativa
# Puedes añadir esta tabla resumida para tener una referencia rápida de qué controla cada parámetro:
#
# | Parámetro | ¿Dónde se configura? | Tipo | ¿Qué controla en el Agente? |
# |---|---|---|---|
# | system_prompt | create_agent | String | La personalidad, rol e idioma base. |
# | response_format | create_agent | Pydantic Class | Fuerza respuestas estructuradas (JSON con esquema). |
# | temperature | Instancia del Modelo | Float (0 a 1) | Azar: 0.1 para códigos/datos, 0.8 para chats fluidos. |
# | max_tokens | Instancia del Modelo | Integer | Longitud máxima permitida para la respuesta del modelo. |
# | max_retries | Instancia del Modelo | Integer | Cuántas veces reintentar la llamada si hay error de red. |

# %% [markdown]
# ### PARAMETROS COGNITIVOS (HIPERPARAMETROS)

# %% [markdown]
# **Método A: Al inicializar el modelo (Para scripts locales avanzados)**

# %%
# !pip install -U langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.13/dist-packages (4.4.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=2.20.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (2.22.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.1 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (1.6.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (2.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.57.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.0)

# %% [markdown]
# La recomendacion es si decides usar el formato con parametrizacion cognitiva personalizada, entonces usar este template que es igual al de arriba, pero con la libreria de langchain-google-genai que debes instalar adicional para usar la clase ChatGoogleGenerativeAI en combinacion a los agent harness, observacion: en el caso de gemini 3.6, usa algunos parametros por defecto, esto pasara igual con algunas version de chatGPT, Claude, etc, verificar bien las caracteristicas del modelo de su proveedor.

# %%
import os

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import create_agent

from google.colab import userdata

# Traer la API_KEY desde las variables de entorno (en esta caso desde un notebook en google colab)
# Esto evita exponer claves privadas al compartir el notebook (recuerde colocar la suya, en este caso la free de google)
os.environ["GEMINI_API_KEY"] = userdata.get('GEMINI_API_KEY')

# Aquí se configuran los hiperparámetros individuales del motor cognitivo
custom_model = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    # temperature=0.1,        # Más determinista (0.0) o más creativo (1.0)-gemini 3.6 use parametros por defecto
    max_tokens=500,           # Límite estricto de tamaño de la respuesta
    # top_p=0.95,             # Muestreo por núcleo (Nucleus sampling)-gemini 3.6 use parametros por defecto
    max_retries=3             # Reintentos automáticos si la API de Google falla
)

agent = create_agent(
    model = custom_model,
    system_prompt="You are an expert Artificial Intelligence tutor. Provide concise and clear explanations. Answer in spanish",
)

result = agent.invoke(
    {
        "messages":
        [
            {
                "role": "user",
                "content": "Explain what an 'Agent Harness' is in one sentence."

            }
        ]
    }
)

# Inspecionamos el Output de el LLM
# Recuperamos el último mensaje del historial retornado por el arnés.
last_message = result["messages"][-1]

# Opción A: Inspección de la estructura interna unificada (content_blocks)
print("--- Content Blocks Structure ---")
# Respuesta completa - print(last_message.content_blocks)
# Respuesta limpia
print(f"AI 🤖: {last_message.content_blocks[0].get("text", "")}")

# Opción B: Extracción del texto limpio (La recomendada para producción)
print("\n--- Final Text Output ---")
# Respuesta completa - print(last_message.content)
# Respuesta limpia
print(f"AI 🤖: {last_message.content[0].get("text", "")}")
# Out:
# --- Content Blocks Structure ---
# AI 🤖: Un **Agent Harness** es la infraestructura de software que envuelve a un agente de IA para gestionar su memoria, sus herramientas, su entorno de ejecución y el flujo de sus interacciones.
#
# --- Final Text Output ---
# AI 🤖: Un **Agent Harness** es la infraestructura de software que envuelve a un agente de IA para gestionar su memoria, sus herramientas, su entorno de ejecución y el flujo de sus interacciones.

# %% [markdown]
# **Modelo B: en combinacion con Models (init_chat_models)**

# %% [markdown]
# Las interfaces de modelos estándar de LangChain te permiten acceder a integraciones con diversos proveedores, lo que facilita experimentar con distintos modelos y alternar entre ellos para encontrar el que mejor se adapte a tu caso de uso.
#
# Uso básico
#
# Los modelos pueden utilizarse de dos formas:
#
# **Con Agentes:** los modelos pueden especificarse dinámicamente al crear un agente.
#
# **De forma independiente:** los modelos pueden invocarse directamente (fuera del bucle del agente) para tareas como la generación, clasificación o extracción de texto, sin necesidad de un marco de trabajo para agentes.
# La misma interfaz de modelo funciona en ambos contextos, lo que te brinda la flexibilidad de comenzar con algo sencillo y escalar hacia flujos de trabajo más complejos basados ​​en agentes según sea necesario.
#
# Inicializar un modelo
# La forma más sencilla de empezar a utilizar un modelo independiente en LangChain es emplear `init_chat_model` para inicializar uno a partir del proveedor de modelos de chat que prefieras.

# %%
import os
from langchain.chat_models import init_chat_model
from langchain.agents import create_agent

from google.colab import userdata

# 1. API_KEY from a notebook google colab
os.environ["GEMINI_API_KEY"] = userdata.get('GEMINI_API_KEY')

# 2. THE MOTOR (Configured globally via production-ready initializer)
# Si mañana quieres cambiar a OpenAI, solo cambias el string a "openai:gpt-4o"
# y no tienes que cambiar ningún import en la parte superior.
production_model = init_chat_model(
    model=os.getenv("GEMINI_MODEL_NAME", "google_genai:gemini-3.6-flash"),
    # temperature=0.1,   # Más determinista (0.0) o más creativo (1.0)-gemini 3.6 use parametros por defecto
    max_retries=5,       # Red tolerante a fallos
    timeout=60,          # Control de latencia en producción
)

# 3. THE HARNESS (The runtime infrastructure surrounding the motor)
agent = create_agent(
    model=production_model, # Fusionamos el motor flexible dentro del arnés
    system_prompt="You are an expert AI tutor. Provide concise explanations. Respond in Spanish.",
)

# 4. Clean execution
response = agent.invoke(
    {"messages": [{"role": "user", "content": "Explain what an 'Agent Harness' is."}]}
)

print(f"AI 🤖: {response['messages'][-1].content[0].get('text', '')}")
# Out:
# AI 🤖: Un **Agent Harness** (o "arnés de agente") es el marco de software o la infraestructura que envuelve a un agente de Inteligencia Artificial (basado en un modelo de lenguaje) para gestionar su funcionamiento, proporcionarle herramientas y controlar su comportamiento.
#
# Si el agente de IA es el "cerebro", el *harness* es la estructura que le permite interactuar con el mundo de forma segura y eficiente.
#
# Sus funciones principales son:
#
# 1. **Conexión con herramientas:** Le da al agente acceso a APIs, bases de datos, navegadores web o ejecución de código.
# 2. **Seguridad y límites (*Guardrails*):** Restringe las acciones del agente para evitar que ejecute comandos peligrosos, entre en bucles infinitos o supere presupuestos de tokens/dinero.
# 3. **Monitoreo y evaluación:** Registra el razonamiento (*logs*), mide el rendimiento del agente y permite hacer pruebas comparativas (*benchmarks*).
# 4. **Control de flujo:** Maneja el ciclo de vida del agente (inicio, pausa, memoria a corto/largo plazo y detención).
#
# En resumen, un *Agent Harness* transforma un modelo de IA teórico en una aplicación práctica, controlable y lista para producción.

# %% [markdown]
# ------------------------------
# ## La Diferencia Técnica: Motor vs. Chasis
# ### 1. La primera forma (init_chat_model): El Motor Puro
# init_chat_model (o instanciar ChatGoogleGenerativeAI) crea únicamente el objeto del modelo de lenguaje (LLM).
#
# **Qué hace:** Se limita a enviar un texto a la API (OpenAI/Google) y esperar la respuesta de texto. Es un canal de ida y vuelta plano.
#
# **Limitaciones:** No tiene memoria automática, no sabe cómo reaccionar si el modelo decide que necesita usar una herramienta (Tool Calling), y no tiene un ciclo para repetir preguntas si la IA se equivoca.
#
# ### 2. La segunda forma (create_agent): El Arnés o Chasis
# create_agent crea el Agente completo (El bucle de ejecución o Harness).
#
# **Qué hace: Envuelve al motor (LLM) y le añade superpoderes:** orquestación de herramientas, inyección automática de system_prompt, esquemas de contexto (context_schema) y persistencia con checkpointer.
#
# **Ventaja:** Si el modelo responde diciendo "Quiero usar la herramienta del clima", el arnés detiene al modelo, ejecuta la función de Python por debajo, toma el resultado, se lo reinyecta al modelo y continúa el flujo sin que tú escribas código extra.
#
# ------------------------------
# ## La mejor alternativa para Producción: La Combinación de Ambos
# En producción, instanciar modelos de forma directa (como ChatGoogleGenerativeAI) genera código rígido y acoplado a un solo proveedor. La sintaxis moderna y recomendada es usar init_chat_model para inicializar el motor cognitivo (por su flexibilidad de configuración) y pasárselo de inmediato al arnés create_agent.
#
# ### ¿Por qué init_chat_model es superior en producción?
# Porque te permite cambiar de proveedor de IA con variables de entorno sin modificar una sola línea de código Python (es Model Agnostic).
#
# ## Cuadro Comparativo
#
# | Característica | init_chat_model (Solo LLM) | create_agent (Harness) | La Combinación (Producción) |
# |---|---|---|---|
# | ¿Maneja Herramientas automáticamente? | No ❌ (Debes programar el bucle a mano) | Sí ✅ | Sí ✅ |
# | ¿Soporta checkpointer / Memoria? | No ❌ | Sí ✅ | Sí ✅ |
# | ¿Cambio de proveedor sin cambiar código? | Sí ✅ (Mediante strings) | No si se usa la clase directa | Sí, Máxima flexibilidad ✅ |
# | Propósito principal | Inicialización limpia y agnóstica del LLM. | Gestión del flujo, reglas y middleware. | El estándar de ingeniería definitivo. |
